# %% [markdown]
# # Traffic Sign Recognition using CNN, Reinforcement Learning, and NLP
#
# A traffic sign recognition program using Convolutional Neural Networks (CNN) and Computer Vision to detect traffic sign images and classify them correctly.

# %% [markdown]
# ## Goal / Purpose
#
# This project is created for the fulfillment of requirements for the final project of **6INTELSYS**.
#
# The chosen topic is the development of a traffic sign recognition program using:
# - Convolutional Neural Networks (CNN)
# - Natural Language Processing
# - Reinforcement Learning
#
# This type of system is commonly used in:
# - Autonomous vehicles (self-driving cars)
# - Real-time traffic sign detection systems
#
# It can also help:
# - New drivers learn and recognize traffic signs
# - Improve road safety awareness
#
# This notebook contains:
# - Project overview
# - Required installations
# - Instructions on running the program
# - Dataset usage

# %% [markdown]
# ## Questions to be Answered
#
# 1. How accurate will the program be when using CNN?
# 2. Will Reinforcement Learning be effective for training the model?
# 3. Can the traffic sign recognition program be accurate enough for future applications?

# %% [markdown]
# ## Assumptions, Methodology, and Scope
#
# ### Assumptions
# - The CNN model will successfully classify traffic signs.
# - Reinforcement Learning will enhance model performance.
# - The dataset is properly labeled and suitable for training.
#
# ### Methodology
# - Use a labeled dataset of traffic signs.
# - Preprocess images (resize, normalize).
# - Train a CNN model.
# - Apply Reinforcement Learning techniques to improve performance.
# - Validate and test the model using dataset splits.
#
# ### Scope
# - The dataset is limited to **Philippine traffic signs** only.
# - Only the signs available in the dataset will be recognized.
# - The system will not handle real-time deployment (simulation only).

# %% [markdown]
# ## Data Description
#
# ### Content
# - The dataset is provided as a ZIP file.
# - It contains **14 categories (classes)**.
# - Total of **2,024 images**.
# - Images are grouped by traffic sign type.
#
# ### Acknowledgements
# This dataset is provided by **Jerry** (Philippine Traffic Sign Dataset Computer Vision Model)
#
# Original source:
# https://universe.roboflow.com/jerry-imbhm/philippine-traffic-sign-dataset-9kz1e-qvpnr

# %%
# Install required libraries
# !pip install tensorflow opencv-python matplotlib numpy

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
